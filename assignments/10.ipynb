# %%
import pandas as pd
import seaborn as sns

# %%
hostels = pd.read_csv('../data/hostel.csv')
penguins = sns.load_dataset("penguins")

# %% [markdown]
# ### Portfolio assignment 10
# 15 min: Perform a bivariate analysis (Pearson correlation and scatter plot) on at least 1 combination of 2 columns with numeric data in the dataset that you chose in portfolio assignment 4. Does the correlation and scatter plot match your expectations? Add your answer to your notebook. Commit the Notebook to your portfolio when you're finished.

# %%
hostels.corr().style.background_gradient(cmap='coolwarm', axis=None).set_precision(2)
# Out:
# /tmp/ipykernel_13570/568957024.py:1: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   hostels.corr().style.background_gradient(cmap='coolwarm', axis=None).set_precision(2)
# <style type="text/css">
# #T_d9298_row0_col0, #T_d9298_row1_col1, #T_d9298_row2_col2, #T_d9298_row3_col3, #T_d9298_row4_col4, #T_d9298_row5_col5, #T_d9298_row6_col6, #T_d9298_row7_col7, #T_d9298_row8_col8, #T_d9298_row9_col9, #T_d9298_row10_col10, #T_d9298_row11_col11 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_d9298_row0_col1, #T_d9298_row1_col0 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_d9298_row0_col2, #T_d9298_row1_col7, #T_d9298_row2_col0, #T_d9298_row5_col11, #T_d9298_row7_col1, #T_d9298_row11_col5 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_d9298_row0_col3, #T_d9298_row0_col5, #T_d9298_row1_col6, #T_d9298_row3_col0, #T_d9298_row5_col0, #T_d9298_row6_col1, #T_d9298_row8_col11, #T_d9298_row11_col8 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_d9298_row0_col4, #T_d9298_row4_col0, #T_d9298_row7_col11, #T_d9298_row11_col7 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_d9298_row0_col6, #T_d9298_row6_col0 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_d9298_row0_col7, #T_d9298_row7_col0 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_d9298_row0_col8, #T_d9298_row8_col0 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_d9298_row0_col9, #T_d9298_row9_col0 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_d9298_row0_col10, #T_d9298_row10_col0 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_d9298_row0_col11, #T_d9298_row11_col0 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_d9298_row1_col2, #T_d9298_row2_col1, #T_d9298_row3_col11, #T_d9298_row5_col10, #T_d9298_row10_col5, #T_d9298_row11_col3 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_d9298_row1_col3, #T_d9298_row3_col1 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_d9298_row1_col4, #T_d9298_row4_col1 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_d9298_row1_col5, #T_d9298_row5_col1 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_d9298_row1_col8, #T_d9298_row8_col1 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_d9298_row1_col9, #T_d9298_row9_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_d9298_row1_col10, #T_d9298_row10_col1 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_d9298_row1_col11, #T_d9298_row11_col1 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_d9298_row2_col3, #T_d9298_row2_col4, #T_d9298_row3_col2, #T_d9298_row4_col2 {
#   background-color: #e16751;
#   color: #f1f1f1;
# }
# #T_d9298_row2_col5, #T_d9298_row5_col2 {
#   background-color: #d44e41;
#   color: #f1f1f1;
# }
# #T_d9298_row2_col6, #T_d9298_row6_col2, #T_d9298_row8_col9, #T_d9298_row9_col8 {
#   background-color: #f7b497;
#   color: #000000;
# }
# #T_d9298_row2_col7, #T_d9298_row7_col2, #T_d9298_row10_col11, #T_d9298_row11_col10 {
#   background-color: #ec7f63;
#   color: #f1f1f1;
# }
# #T_d9298_row2_col8, #T_d9298_row8_col2 {
#   background-color: #e36c55;
#   color: #f1f1f1;
# }
# #T_d9298_row2_col9, #T_d9298_row9_col2 {
#   background-color: #dc5d4a;
#   color: #f1f1f1;
# }
# #T_d9298_row2_col10, #T_d9298_row10_col2 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_d9298_row2_col11, #T_d9298_row6_col11, #T_d9298_row9_col11, #T_d9298_row11_col2, #T_d9298_row11_col6, #T_d9298_row11_col9 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_d9298_row3_col4, #T_d9298_row4_col3 {
#   background-color: #f7b396;
#   color: #000000;
# }
# #T_d9298_row3_col5, #T_d9298_row5_col3 {
#   background-color: #f59d7e;
#   color: #000000;
# }
# #T_d9298_row3_col6, #T_d9298_row6_col3 {
#   background-color: #e7d7ce;
#   color: #000000;
# }
# #T_d9298_row3_col7, #T_d9298_row7_col3 {
#   background-color: #f1ccb8;
#   color: #000000;
# }
# #T_d9298_row3_col8, #T_d9298_row7_col9, #T_d9298_row8_col3, #T_d9298_row9_col7 {
#   background-color: #f6a586;
#   color: #000000;
# }
# #T_d9298_row3_col9, #T_d9298_row9_col3 {
#   background-color: #f39475;
#   color: #000000;
# }
# #T_d9298_row3_col10, #T_d9298_row10_col3 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_d9298_row4_col5, #T_d9298_row5_col4 {
#   background-color: #e9785d;
#   color: #f1f1f1;
# }
# #T_d9298_row4_col6, #T_d9298_row6_col4 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_d9298_row4_col7, #T_d9298_row7_col4 {
#   background-color: #f6bfa6;
#   color: #000000;
# }
# #T_d9298_row4_col8, #T_d9298_row8_col4 {
#   background-color: #f7b599;
#   color: #000000;
# }
# #T_d9298_row4_col9, #T_d9298_row9_col4 {
#   background-color: #f6a385;
#   color: #000000;
# }
# #T_d9298_row4_col10, #T_d9298_row9_col10, #T_d9298_row10_col4, #T_d9298_row10_col9 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_d9298_row4_col11, #T_d9298_row11_col4 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_d9298_row5_col6, #T_d9298_row6_col5 {
#   background-color: #e8d6cc;
#   color: #000000;
# }
# #T_d9298_row5_col7, #T_d9298_row7_col5 {
#   background-color: #f7b194;
#   color: #000000;
# }
# #T_d9298_row5_col8, #T_d9298_row7_col8, #T_d9298_row8_col5, #T_d9298_row8_col7 {
#   background-color: #f6a283;
#   color: #000000;
# }
# #T_d9298_row5_col9, #T_d9298_row9_col5 {
#   background-color: #f08b6e;
#   color: #f1f1f1;
# }
# #T_d9298_row6_col7, #T_d9298_row7_col6 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_d9298_row6_col8, #T_d9298_row8_col6 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_d9298_row6_col9, #T_d9298_row9_col6 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_d9298_row6_col10, #T_d9298_row10_col6 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_d9298_row7_col10, #T_d9298_row10_col7 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_d9298_row8_col10, #T_d9298_row10_col8 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_d9298">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d9298_level0_col0" class="col_heading level0 col0" >Unnamed: 0</th>
#       <th id="T_d9298_level0_col1" class="col_heading level0 col1" >price.from</th>
#       <th id="T_d9298_level0_col2" class="col_heading level0 col2" >summary.score</th>
#       <th id="T_d9298_level0_col3" class="col_heading level0 col3" >atmosphere</th>
#       <th id="T_d9298_level0_col4" class="col_heading level0 col4" >cleanliness</th>
#       <th id="T_d9298_level0_col5" class="col_heading level0 col5" >facilities</th>
#       <th id="T_d9298_level0_col6" class="col_heading level0 col6" >location.y</th>
#       <th id="T_d9298_level0_col7" class="col_heading level0 col7" >security</th>
#       <th id="T_d9298_level0_col8" class="col_heading level0 col8" >staff</th>
#       <th id="T_d9298_level0_col9" class="col_heading level0 col9" >valueformoney</th>
#       <th id="T_d9298_level0_col10" class="col_heading level0 col10" >lon</th>
#       <th id="T_d9298_level0_col11" class="col_heading level0 col11" >lat</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d9298_level0_row0" class="row_heading level0 row0" >Unnamed: 0</th>
#       <td id="T_d9298_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_d9298_row0_col1" class="data row0 col1" >0.10</td>
#       <td id="T_d9298_row0_col2" class="data row0 col2" >-0.03</td>
#       <td id="T_d9298_row0_col3" class="data row0 col3" >-0.01</td>
#       <td id="T_d9298_row0_col4" class="data row0 col4" >-0.00</td>
#       <td id="T_d9298_row0_col5" class="data row0 col5" >-0.01</td>
#       <td id="T_d9298_row0_col6" class="data row0 col6" >-0.05</td>
#       <td id="T_d9298_row0_col7" class="data row0 col7" >-0.02</td>
#       <td id="T_d9298_row0_col8" class="data row0 col8" >0.01</td>
#       <td id="T_d9298_row0_col9" class="data row0 col9" >-0.08</td>
#       <td id="T_d9298_row0_col10" class="data row0 col10" >0.05</td>
#       <td id="T_d9298_row0_col11" class="data row0 col11" >0.09</td>
#     </tr>
#     <tr>
#       <th id="T_d9298_level0_row1" class="row_heading level0 row1" >price.from</th>
#       <td id="T_d9298_row1_col0" class="data row1 col0" >0.10</td>
#       <td id="T_d9298_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_d9298_row1_col2" class="data row1 col2" >-0.05</td>
#       <td id="T_d9298_row1_col3" class="data row1 col3" >-0.13</td>
#       <td id="T_d9298_row1_col4" class="data row1 col4" >0.00</td>
#       <td id="T_d9298_row1_c

# %%
hostels.plot(kind='scatter', x='summary.score', y='facilities')
# Out:
# <AxesSubplot:xlabel='summary.score', ylabel='facilities'>

# %%
hostels.plot(kind='scatter', x='summary.score', y='valueformoney')
# Out:
# <AxesSubplot:xlabel='summary.score', ylabel='valueformoney'>

# %% [markdown]
# ### Expectations and result
# I expected the summary score to be closely related to the value for money score, if someone is overall happy with the hostel it could mean that they think it has a lot of value for their money. This seemed to be the case as well.

# %% [markdown]
# ### Extra
# What's interesting is that the atmosphere has a large correlation with the score. This is interesting because it isn't anything that's directly involved in the hostel itself such as the staff or the price of the hostel.

# %%
hostels.plot(kind='scatter', x='summary.score', y='atmosphere')
# Out:
# <AxesSubplot:xlabel='summary.score', ylabel='atmosphere'>
