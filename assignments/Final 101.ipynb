# %% [markdown]
# #### Looking back at assignment 1.
# The presentation actually contains enough information, however our group just didn't understand the concepts as well.
# #### Short report explaining DS.
# With Datascience we can get insight from structured or unstructured data using algorithms or systems.
# In our case we've been working with Jupiter notebook with pyhon, using python libraries that can help us get insight from our data.
# Confidence interval, clustering, multivariate analysis, bivariate analysis and univariete analysis. These are just some examples of strategies and topics we've used to get insight of our data.

# %% [markdown]
# For example below we have a piece of code that extracts our data set and shows us the correlation between two types of values we have data of.
# This can then be used to analyse the data to get meaningful information out of it, which is what a data scientist does.

# %%
import pandas as pd
import seaborn as sns
hostels = pd.read_csv('../data/hostel.csv')
penguins = sns.load_dataset("penguins")

# %%
hostels.corr().style.background_gradient(cmap='coolwarm', axis=None).set_precision(2)
# Out:
# /tmp/ipykernel_3189/568957024.py:1: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   hostels.corr().style.background_gradient(cmap='coolwarm', axis=None).set_precision(2)
# <style type="text/css">
# #T_440ae_row0_col0, #T_440ae_row1_col1, #T_440ae_row2_col2, #T_440ae_row3_col3, #T_440ae_row4_col4, #T_440ae_row5_col5, #T_440ae_row6_col6, #T_440ae_row7_col7, #T_440ae_row8_col8, #T_440ae_row9_col9, #T_440ae_row10_col10, #T_440ae_row11_col11 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_440ae_row0_col1, #T_440ae_row1_col0 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_440ae_row0_col2, #T_440ae_row1_col7, #T_440ae_row2_col0, #T_440ae_row5_col11, #T_440ae_row7_col1, #T_440ae_row11_col5 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_440ae_row0_col3, #T_440ae_row0_col5, #T_440ae_row1_col6, #T_440ae_row3_col0, #T_440ae_row5_col0, #T_440ae_row6_col1, #T_440ae_row8_col11, #T_440ae_row11_col8 {
# ...
